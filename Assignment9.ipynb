# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/healthcare_data.csv')

# %%
df
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 1         1002              Jane Doe   62  Female         B-       Diabetes
# 2         1003        Robert Johnson   35    Male         O+         Cancer
# 3         1004          Susan Wilson   78  Female         A-  Heart Disease
# 4         1005         Michael Brown   55    Male        AB+         Asthma
# 5         1006           Lisa Miller   30  Female         B+   Hypertension
# 6         1007           James Davis   48    Male         O-       Diabetes
# 7         1008          Karen Harris   65  Female        AB-         Cancer
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 9         1010           Linda Smith   42  Female         O+         Asthma
# 10        1011           William Lee   33    Male        AB+   Hypertension
# ...

# %%
df['Age']
# Out:
# 0     45
# 1     62
# 2     35
# 3     78
# 4     55
# 5     30
# 6     48
# 7     65
# 8     72
# 9     42
# 10    33
# 11    70
# 12    55
# 13    51
# 14    44
# 15    62
# 16    29
# 17    40
# 18    67
# 19    49
# 20    38
# 21    54
# 22    58
# 23    41
# 24    47
# 25    35
# 26    60
# 27    53
# 28    49
# 29    56
# 30    44
# 31    65
# 32    30
# 33    70
# 34    35
# 35    52
# 36    57
# 37    43
# 38    62
# 39    41
# 40    46
# 41    51
# 42    55
# 43    42
# 44    59
# 45    64
# 46    40
# 47    39
# 48    34
# 49    47
# Name: Age, dtype: int64

# %%
df_hist = df['Age'].plot(kind ='hist', color = 'darkred', edgecolor = 'w')

# %%
df.groupby('Gender').agg('count')
# Out:
#         Patient_ID  Patient_Name  Age  Blood_Type  Diagnosis  Treatment_Cost
# Gender
# Female          25            25   25          25         25              15
# Male            25            25   25          25         25              19

# %%
#50% of the dataset is Male

# %%
df.groupby('Diagnosis').agg('count')
# Out:
#                Patient_ID  Patient_Name  Age  Gender  Blood_Type  \
# Diagnosis
# Asthma                 10            10   10      10          10
# Cancer                 10            10   10      10          10
# Diabetes               10            10   10      10          10
# Heart Disease          10            10   10      10          10
# Hypertension           10            10   10      10          10
#
#                Treatment_Cost
# Diagnosis
# Asthma                      7
# Cancer                      6
# Diabetes                    7
# Heart Disease               8
# Hypertension                6

# %%
#10 patients have been diagnosed with 'Cancer'

# %%
df2 = df.loc[df["Age"] > 60]

# %%
df2
# Out:
#     Patient_ID      Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 1         1002          Jane Doe   62  Female         B-       Diabetes
# 3         1004      Susan Wilson   78  Female         A-  Heart Disease
# 7         1008      Karen Harris   65  Female        AB-         Cancer
# 8         1009      David Wilson   72    Male         A+  Heart Disease
# 11        1012        Mary Brown   70  Female         B-         Cancer
# 15        1016      Linda Wilson   62  Female         A+         Cancer
# 18        1019  Michael Williams   67    Male        AB+  Heart Disease
# 31        1032    Linda Martinez   65  Female         B+       Diabetes
# 33        1034         Sarah Lee   70  Female         A-  Heart Disease
# 38        1039     Richard Davis   62    Male         O-  Heart Disease
# 45        1046  Elizabeth Wilson   64  Female         O-   Hypertension
#
#     Treatment_Cost
# 1           800.75
# 3          2700.25
# 7              NaN
# 8          3200.00
# ...

# %%
df2.describe()
# Out:
#         Patient_ID        Age  Treatment_Cost
# count    11.000000  11.000000        7.000000
# mean   1020.090909  67.000000     2553.785714
# std      15.175339   5.059644     1835.252613
# min    1002.000000  62.000000      800.750000
# 25%    1008.500000  63.000000      987.750000
# 50%    1016.000000  65.000000     2700.250000
# 75%    1033.000000  70.000000     3250.000000
# max    1046.000000  78.000000     5900.000000

# %%
# the average treatment for  patient ages 60+ is aprox 2553.79$.

# %%
df.groupby('Blood_Type')['Treatment_Cost'].mean()
# Out:
# Blood_Type
# A+     3594.500000
# A-     1470.300000
# AB+    2232.687500
# AB-    1923.833333
# B+      860.250000
# B-      860.750000
# O+     2870.125000
# O-     1935.250000
# Name: Treatment_Cost, dtype: float64

# %%
#A+ is the blood type with the highest average treatment cost

# %%
dfx = df.groupby(['Gender','Diagnosis'])['Age'].mean()

# %%
dfx
# Out:
# Gender  Diagnosis
# Female  Asthma           47.666667
#         Cancer           55.333333
#         Diabetes         54.400000
#         Heart Disease    57.750000
#         Hypertension     45.250000
# Male    Asthma           49.000000
#         Cancer           44.500000
#         Diabetes         52.000000
#         Heart Disease    54.666667
#         Hypertension     39.166667
# Name: Age, dtype: float64

# %%
#this displays all possible outcomes and their respective averages in age
